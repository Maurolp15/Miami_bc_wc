# %% [markdown]
# # Spring Cleaning!

# %% [markdown]
# Harold's stock data is a mess! Help him clean up his data before the auditors arrive!

# %%
# Import Libraries
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Load CSV data into Pandas using `read_csv`

# %%
csv_path = Path("../../Resources/stock_data.csv")
df = pd.read_csv(csv_path)
df.sample(5)
# Out:
#     symbol                  name                      sector    price  \
# 184    XOM     Exxon Mobil Corp.                      Energy    76.07
# 98     CTL       CenturyLink Inc  Telecommunication Services     16.2
# 308   MCHP  Microchip Technology      Information Technology     79.9
# 26   GOOGL  Alphabet Inc Class A      Information Technology  1007.71
# 414    SLG       SL Green Realty                 Real Estate    90.61
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 184               21.37        4.003120               1.88        89.30
# 98                 8.35       12.661196               1.16        27.61
# 308               21.77        1.751297               0.66        99.17
# 26                31.48        0.000000              22.27      1198.00
# 414               14.07        3.499892               0.88       115.34
#
#      52_week_high    market_cap        ebitda  price_per_sales  \
# 184        76.050  3.261487e+11  3.905200e+10         1.770194
# 98         13.161  1.823720e+10           NaN         1.479598
# 308        69.760  1.939310e+10  9.974920e+08         7.447518
# 26        824.300  7.338240e+11  3.421700e+10         6.801692
# 414        91.200  8.617714e+09  7.958890e+08         6.582008
#
#      price_per_book                                        sec_filings
# 184            1.85  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 98             1.39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 308            5.90  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 26             4.70  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 414            1.32  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# ### Identify the number of rows and columns (shape) in the DataFrame.

# %%
df.shape
# Out:
# (504, 14)

# %% [markdown]
# ### Generate a sample of the data to visually ensure data has been loaded in correctly.

# %%
df.sample(10)
# Out:
#     symbol                              name                  sector   price  \
# 304    MET                      MetLife Inc.              Financials   44.28
# 131    CCI  Crown Castle International Corp.             Real Estate  103.81
# 134    CMI                      Cummins Inc.             Industrials  165.73
# 494   WYNN                  Wynn Resorts Ltd  Consumer Discretionary  169.28
# 290      M                       Macy's Inc.  Consumer Discretionary      24
# 103    CHK                 Chesapeake Energy                  Energy    2.82
# 52    APTV                         Aptiv Plc  Consumer Discretionary   89.27
# 400    RCL       Royal Caribbean Cruises Ltd  Consumer Discretionary  122.45
# 388      O         Realty Income Corporation             Real Estate   47.56
# 234    HRL                Hormel Foods Corp.        Consumer Staples   32.21
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 304                8.52        3.458712               0.63        56.58
# 131               21.45        3.862069               1.02       114.97
# 134               16.83        2.500868               8.23       194.18
# 494               31.70        1.127904               7.27       203.63
# 290                7.67        6.098546               1.98        33.73
# 103                4.70        0.000000              -6.44         6.59
# 52                69.74        0.939268               5.05        96.91
# 400               16.26        1.867414               7.53       135.65
# 388               15.54        5.372036               1.12        63.60
# 234               20.39        2.290776               1.57        38.00
#
#      52_week_high    market_cap        ebitda  price_per_sales  \
# 304       44.5800  4.867936e+10  0.000000e+00         1.049686
# 131       86.9300  4.418302e+10  2.292600e+09        10.125291
# 134      143.8301  2.866923e+10  2.924000e+09         1.940617
# 494       92.6700  1.822540e+10  1.501301e+09         2.478658
# 290       17.4050  7.541063e+09  2.446000e+09         0.455032
# 103        2.8000  2.626102e+09  1.470000e+09         0.407652
# 52        82.9700  2.490653e+10  2.370000e+09         1.502580
# 400       93.4000  2.741815e+10  2.876309e+09         3.102661
# 388       48.8900  1.378494e+10  1.075568e+09        15.588069
# 234       29.7500  1.733861e+10  1.422305e+09         2.517479
#
#      price_per_book                                        sec_filings
# 304            0.85  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 131            3.54  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 134            3.89  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 494           51.69  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 290            1.69  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 103            1.84  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 52             7.56  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 400            2.56  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 388            1.92  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 234            3.49  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# ### Identify the number of records in the DataFrame, and compare it with the number of rows in the original file.

# %%
df.count()
# Out:
# symbol                504
# name                  502
# sector                501
# price                 500
# price_per_earnings    497
# dividend_yield        499
# earnings_per_share    498
# 52_week_low           500
# 52_week_high          500
# market_cap            500
# ebitda                492
# price_per_sales       500
# price_per_book        492
# sec_filings           500
# dtype: int64

# %% [markdown]
# ### Identify nulls records

# %%
df.isnull().sum()
# Out:
# symbol                 0
# name                   2
# sector                 3
# price                  4
# price_per_earnings     7
# dividend_yield         5
# earnings_per_share     6
# 52_week_low            4
# 52_week_high           4
# market_cap             4
# ebitda                12
# price_per_sales        4
# price_per_book        12
# sec_filings            4
# dtype: int64

# %% [markdown]
# ### Drop Null Records

# %%
df = df.dropna().copy()

# %% [markdown]
# ### Validate nulls have been dropped

# %%
df = df.dropna().copy()

# %% [markdown]
# ### Default null `ebitda` values to 0. Then, validate no records are null for ebitda.

# %%
df['ebitda'].fillna(0,inplace=True)

# %% [markdown]
# ### Drop Duplicates

# %%
new_df = df.drop_duplicates().copy()

# %%
new_df.head()
# Out:
#   symbol                 name                  sector    price  \
# 0    MMM           3M Company             Industrials  $222.89
# 1    AOS      A.O. Smith Corp             Industrials      NaN
# 2    ABT  Abbott Laboratories             Health Care    56.27
# 3   ABBV          AbbVie Inc.             Health Care   108.48
# 4   ATVI  Activision Blizzard  Information Technology    65.83
#
#    price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0               24.31        2.332862              $7.92      259.770
# 1                 NaN             NaN                NaN          NaN
# 2               22.51        1.908982               0.26       64.600
# 3               19.41        2.499560               3.29      125.860
# 4                 NaN        0.431903               1.28       74.945
#
#    52_week_high    market_cap        ebitda  price_per_sales  price_per_book  \
# 0        175.49  1.387211e+11  9.048000e+09         4.390271           11.34
# 1           NaN           NaN  0.000000e+00              NaN             NaN
# 2         42.28  1.021210e+11  5.744000e+09         3.740480            3.19
# 3         60.05  1.813863e+11  1.031000e+10         6.291571           26.14
# 4         38.93  5.251867e+10  2.704000e+09        10.595120            5.16
#
#                                          sec_filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1                                                NaN
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...
