# %% [markdown]
# ### Instructor Demo: Simple Moving Averages
#
# This program reads in the CSV datasets of Netflix (NFLX) and plots the 20, 50, and 100 Simple Moving Averages (SMA) using the `rolling` function, `window` parameter, and `mean` function.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
filepath = Path('../Resources/nflx.csv')

nflx_data = pd.read_csv(filepath, index_col="date", infer_datetime_format=True, parse_dates=True)

nflx_data.sort_index(inplace=True)
nflx_data.head()
# Out:
#              close
# date
# 2009-05-18  5.5386
# 2009-05-19  5.6614
# 2009-05-20  5.7500
# 2009-05-21  5.5871
# 2009-05-22  5.5429

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set file path


# Read the CSV into a DataFrame and set the 'date' column as a datetime index


# Sort the data in forward chronological order, and display a few records

# %%
nflx_data.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Plot Daily Closing Price of NFLX

# %%
# Plot DataFrame

# %% [markdown]
# ### Calculate 20-Day Simple Moving Average (SMA20)

# %%
nflx_20_a = nflx_data.rolling(window=20).mean()
nflx_20_a.head(25)
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# 2009-05-26       NaN
# 2009-05-27       NaN
# 2009-05-28       NaN
# 2009-05-29       NaN
# 2009-06-01       NaN
# 2009-06-02       NaN
# 2009-06-03       NaN
# 2009-06-04       NaN
# 2009-06-05       NaN
# 2009-06-08       NaN
# 2009-06-09       NaN
# 2009-06-10       NaN
# 2009-06-11       NaN
# 2009-06-12       NaN
# 2009-06-15  5.610495
# 2009-06-16  5.603780
# 2009-06-17  5.609280
# 2009-06-18  5.616850
# 2009-06-19  5.634565
# 2009-06-22  5.647065

# %%
# Calculate 20-day Simple Moving Average for NFLX Closing Prices
# Out:
#                  close
# date
# 2019-05-16         NaN
# 2019-05-15         NaN
# 2019-05-14         NaN
# 2019-05-13         NaN
# 2019-05-10         NaN
# 2019-05-09         NaN
# 2019-05-08         NaN
# 2019-05-07         NaN
# 2019-05-06         NaN
# 2019-05-03         NaN
# 2019-05-02         NaN
# 2019-05-01         NaN
# 2019-04-30         NaN
# 2019-04-29         NaN
# 2019-04-26         NaN
# 2019-04-25         NaN
# 2019-04-24         NaN
# 2019-04-23         NaN
# 2019-04-22         NaN
# 2019-04-18  368.236000
# 2019-04-17  368.007500
# 2019-04-16  368.231000
# 2019-04-15  368.394000
# 2019-04-12  368.688000
# 2019-04-11  369.018500
# 2019-04-10  369.077000
# 2019-04-09  369.094000
# 2019-04-08  368.641500
# 2019-04-05  367.982500
# 2019-04-04  367.125000
# ...                ...
# 2009-06-29    6.027075
# 2009-06-26    6.017575
# 2009-06-25    6.009790
# 2009-06-24    5.960720
# 2009-06-23    5.919935
# 2009-06-22    5.889725
# 2009-06-19    5.866650
# 2009-06-18    5.846435
# 2009-06-17    5.819790
# 2009-06-16    5.772790
# 2009-06-15    5.736075
# 2009-06-12    5.705005
# 2009-06-11    5.688360
# 2009-06-10    5.673435
# 2009-06-09    5.675650
# 2009-06-08    5.675720
# 2009-06-05    5.671505
# 2009-06-04    5.677145
# 2009-06-03    5.676285
# 2009-06-02    5.675070
# 2009-06-01    5.673215
# 2009-05-29    5.666430
# 2009-05-28    5.648070
# 2009-05-27    5.643355
# 2009-05-26    5.647065
# 2009-05-22    5.634565
# 2009-05-21    5.616850
# 2009-05-20    5.609280
# 2009-05-19    5.603780
# 2009-05-18    5.610495
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 50-Day Simple Moving Average (SMA50)

# %%
nflx_50_a = nflx_data.rolling(window=50).mean()
nflx_50_a[40:60]
# Out:
#                close
# date
# 2009-07-15       NaN
# 2009-07-16       NaN
# 2009-07-17       NaN
# 2009-07-20       NaN
# 2009-07-21       NaN
# 2009-07-22       NaN
# 2009-07-23       NaN
# 2009-07-24       NaN
# 2009-07-27       NaN
# 2009-07-28  5.811200
# 2009-07-29  5.822428
# 2009-07-30  5.833800
# 2009-07-31  5.844342
# 2009-08-03  5.861086
# 2009-08-04  5.876456
# 2009-08-05  5.888514
# 2009-08-06  5.901572
# 2009-08-07  5.920030
# 2009-08-10  5.938260
# 2009-08-11  5.952974

# %%
# Calculate 50-day Simple Moving Average for NFLX Closing Prices

# %% [markdown]
# ### Calculate 100-Day Simple Moving Average (SMA100)

# %%
# Calculate 100-day Simple Moving Average for NFLX Closing Prices
nflx_100_a = nflx_data.rolling(window=100).mean()
nflx_100_a[90:110]
# Out:
#                close
# date
# 2009-09-24       NaN
# 2009-09-25       NaN
# 2009-09-28       NaN
# 2009-09-29       NaN
# 2009-09-30       NaN
# 2009-10-01       NaN
# 2009-10-02       NaN
# 2009-10-05       NaN
# 2009-10-06       NaN
# 2009-10-07  6.095000
# 2009-10-08  6.105385
# 2009-10-09  6.115785
# 2009-10-12  6.124085
# 2009-10-13  6.134628
# 2009-10-14  6.147870
# 2009-10-15  6.162528
# 2009-10-16  6.176900
# 2009-10-19  6.192986
# 2009-10-20  6.206615
# 2009-10-21  6.216486

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and SMAs

# %%
# Set figure of the daily closing prices of NFLX
axis = nflx_data.plot(figsize=(25,10))

# Overlay STD20, STD50, and STD100 on the same figure
nflx_100_a.plot(ax=axis)
nflx_50_a.plot(ax=axis)
nflx_20_a.plot(ax=axis)

# Set the legend of the figure
axis.legend(['Daily','100 SMA','50 SMA','20 SMA'])

# Overlay SMA20, SMA50, and SMA100 on the same figure

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and STDs

# %%
# Set figure of the daily closing prices of NFLX
nflx_100_std = nflx_data.rolling(window=100).std()
nflx_50_std = nflx_data.rolling(window=50).std()
nflx_20_std = nflx_data.rolling(window=20).std()

# Set figure of the daily closing prices of NFLX
axis = nflx_data.plot(figsize=(25,10))

# Overlay STD20, STD50, and STD100 on the same figure
nflx_100_a.plot(ax=axis)
nflx_50_a.plot(ax=axis)
nflx_20_a.plot(ax=axis)


# Overlay STD20, STD50, and STD100 on the same figure
nflx_100_std.plot(figsize=(15,10))
nflx_50_std.plot(figsize=(15,10))
nflx_20_std.plot()

# Set the legend of the figure
axis.legend(['Daily Close','100 STD', '50 STD', '20 STD'])

# %% [markdown]
# ### Should Harold's firm invest long term in NFLX?
