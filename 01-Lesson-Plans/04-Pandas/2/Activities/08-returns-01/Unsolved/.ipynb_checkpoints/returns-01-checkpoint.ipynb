# %% [markdown]
# # Calculating Stock Returns using Pandas DataFrames

# %% [markdown]
# ## 1. Import Libaries and Dependencies

# %%
# Import necessary libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
csv_path = Path('../Resources/MSFT.csv')
csv_path
# Out:
# PosixPath('../Resources/MSFT.csv')

# %% [markdown]
# ## 3. Read CSV in as DataFrame

# %%
# Read in the CSV as a DataFrame
msft_pd = pd.read_csv(csv_path, parse_dates=True, infer_datetime_format=True)
msft_pd.head()
# Out:
#      date  close    volume   open   high    low
# 0  8/3/09  23.83  46843710  23.82  23.86  23.50
# 1  8/4/09  23.77  49116380  23.68  23.79  23.53
# 2  8/5/09  23.81  53263040  23.84  24.25  23.79
# 3  8/6/09  23.46  59655950  23.93  23.98  23.27
# 4  8/7/09  23.56  46165010  23.75  23.82  23.50

# %% [markdown]
# ## 4. Drop Extra Columns

# %%
# Drop unnecessary columns
msft_pd.drop(['volume','open','high','low'], axis=1, inplace=True)
msft_pd
# Out:
#          date   close
# 0      8/3/09   23.83
# 1      8/4/09   23.77
# 2      8/5/09   23.81
# 3      8/6/09   23.46
# 4      8/7/09   23.56
# ...       ...     ...
# 2512  7/26/19  141.34
# 2513  7/29/19  141.03
# 2514  7/30/19  140.35
# 2515  7/31/19  136.27
# 2516   8/1/19  138.06
#
# [2517 rows x 2 columns]

# %% [markdown]
# ## 5. Set Date as Index

# %%
# Set the date as the index to the DataFrame
msft_pd.set_index(pd.to_datetime(msft_pd["date"], infer_datetime_format = True), inplace = True)
msft_pd.head()
# Out:
#               date  close
# date
# 2009-08-03  8/3/09  23.83
# 2009-08-04  8/4/09  23.77
# 2009-08-05  8/5/09  23.81
# 2009-08-06  8/6/09  23.46
# 2009-08-07  8/7/09  23.56

# %% [markdown]
# ## 6. Drop Extra Date Column

# %%
# Drop the extra date column
msft_pd.drop('date', axis=1, inplace=True)
msft_pd.head()
# Out:
#             close
# date
# 2009-08-03  23.83
# 2009-08-04  23.77
# 2009-08-05  23.81
# 2009-08-06  23.46
# 2009-08-07  23.56

# %% [markdown]
# ## 7. Plot Daily Close

# %%
# Plot the daily closing stock price of the S&P 500 over the last 5 years
msft_pd.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 8. Calculate Daily Returns

# %%
# Calculate the daily return using the 'pct_change()' function
daily_returns = msft_pd.pct_change()
daily_returns.head()
# Out:
#                close
# date
# 2009-08-03       NaN
# 2009-08-04 -0.002518
# 2009-08-05  0.001683
# 2009-08-06 -0.014700
# 2009-08-07  0.004263

# %% [markdown]
# ## 9. Plot Daily Returns

# %%
# Plot the daily returns of MSFT over the last 10 years
daily_returns.plot(figsize =(20,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 10. Calculate Cumulative Returns

# %%
# Calculate the cumulative returns using the 'cumprod()' function
commulative_returns = (1 + all_returns).compond()
comulative_returns.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4c/n0d3gkhn0rq607n3sdpf7n000000gn/T/ipykernel_16186/2067776749.py in <module>
#       1 # Calculate the cumulative returns using the 'cumprod()' function
# ----> 2 commulative_returns = (1 + all_returns).compond()
#       3 comulative_returns.head()
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'compond'

# %% [markdown]
# ## 11. Plot Cumulative Returns

# %%
# Plot the daily returns of the S&P 500 over the last 5 years
comulative_returns.plot(figzise=(20,10), title
